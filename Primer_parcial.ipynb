# %%
import pandas as pd

# %%
from google.colab import drive
import sys
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv("/content/drive/MyDrive/Parcial 1 auto/spotify-2023.csv" , encoding = 'latin-1')
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
# Punto A
df.info()

df.dtypes.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
# Punto B

B=df[df['artist(s)_name']=='Taylor Swift']
B.value_counts()
# Out:
# track_name                                           artist(s)_name  artist_count  released_year  released_month  released_day  in_spotify_playlists  in_spotify_charts  streams     in_apple_playlists  in_apple_charts  in_deezer_playlists  in_deezer_charts  in_shazam_charts  bpm  key  mode   danceability_%  valence_%  energy_%  acousticness_%  instrumentalness_%  liveness_%  speechiness_%
# All Of The Girls You Loved Before                    Taylor Swift    1             2019           8               23            1282                  6                  185240616   26                  6                19                   0                 5                 96   D    Major  72              40         47        71              0                   13          4                1
# ...

# %%
print(B['artist(s)_name'].value_counts())
# Out:
# artist(s)_name
# Taylor Swift    34
# Name: count, dtype: int64

# %%
# PUNTO C
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
# PUNTO D
def filtroA(dfcanciones):
    dffiltroaño = dfcanciones[dfcanciones["released_year"] < 2020]
    return dffiltroaño
df_año = filtroA(dfcanciones)
df_año
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-732550565.py in <cell line: 0>()
#       3     dffiltroaño = dfcanciones[dfcanciones["released_year"] < 2020]
#       4     return dffiltroaño
# ----> 5 df_año = filtroA(dfcanciones) #crear una nueva variable que va a contener los valores de una base de datos filtrada por altura
#       6 df_año
#
# NameError: name 'dfcanciones' is not defined

# %%
def filtroTaylor(dfcanciones):
    dfFiltroTaylor = dfcanciones[dfcanciones["artist(s)_name"] == 'Taylor Swift']
    return dfFiltroTaylor
dfTaylor = filtroTaylor(dfcanciones)
dfTaylor
contadorTaylor = dfTaylor['artist(s)_name'].count()
print(contadorTaylor)
def filtroADELE(dfcanciones):
    dfFiltroadele = dfcanciones[dfcanciones["artist(s)_name"] == 'Adele']
    return dfFiltroadele
dfadele = filtroADELE(dfcanciones)
dfadele
contadoradele = dfadele['artist(s)_name'].count()
print(contadoradele)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3263980087.py in <cell line: 0>()
#       2     dfFiltroTaylor = dfcanciones[dfcanciones["artist(s)_name"] == 'Taylor Swift']
#       3     return dfFiltroTaylor
# ----> 4 dfTaylor = filtroTaylor(dfcanciones)
#       5 dfTaylor
#       6 contadorTaylor = dfTaylor['artist(s)_name'].count()
#
# NameError: name 'dfcanciones' is not defined
